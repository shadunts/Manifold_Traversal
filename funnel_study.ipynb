# %%
import numpy as np
import os
import time
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.lines import Line2D

np.random.seed(42)

from models.manifold_traversal import ManifoldTraversal

mpl.rcParams.update({
    "text.usetex": False,
    "font.family": "serif",
    "font.serif": ["Times"]
})

# %%
# data setup
data_dir = './data'
save_dir = 'results'
train_waves_filename = 'datawaves_100000_spinsFalse_nonuniform.npy'
test_waves_filename = 'datawaves_20000_spinsFalse_nonuniform.npy'

# create results directory
os.makedirs(save_dir, exist_ok=True)

# parameters
sigma = 0.01
d = 2

print("Loading GW training data...")
train_file = os.path.join(data_dir, train_waves_filename)
train_waves = np.load(train_file)

print("Loading GW test data...")
test_file = os.path.join(data_dir, test_waves_filename)
test_waves = np.load(test_file)

X_natural_train = train_waves.T
X_natural_test = test_waves.T

N_train = X_natural_train.shape[1]
N_test = X_natural_test.shape[1]
D = X_natural_train.shape[0]

X_train = X_natural_train + sigma * np.random.randn(D, N_train)
X_test = X_natural_test + sigma * np.random.randn(D, N_test)

print(f"Training data shape: {X_train.shape}")
print(f"Test data shape: {X_test.shape}")
print(f"Ambient dimension (D): {D}")
print(f"Intrinsic dimension (d): {d}")
print(f"Noise level (sigma): {sigma}")
# Out:
# Loading GW training data...
# Loading GW test data...
# Training data shape: (2048, 100000)
# Test data shape: (2048, 20000)
# Ambient dimension (D): 2048
# Intrinsic dimension (d): 2
# Noise level (sigma): 0.01

# %%
def get_hyperparameter_configs(sigma, d, D):
    sigma_sq_D = sigma ** 2 * D
    sigma_sq_d = sigma ** 2 * d

    base_configs = [
        # Network 1
        {
            'R_is_const': False,
            'R_denoising': np.sqrt(2.06 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 2
        {
            'R_is_const': True,
            'R_denoising': np.sqrt(2.06 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 3
        {
            'R_is_const': False,
            'R_denoising': np.sqrt(2.06 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(8 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 4
        {
            'R_is_const': True,
            'R_denoising': np.sqrt(2.75 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.75 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 5
        {
            'R_is_const': False,
            'R_denoising': np.sqrt(2.06 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.3,
            'exp_coeff': 1 / 3
        },
        # Network 6
        {
            'R_is_const': False,
            'R_denoising': np.sqrt(2.06 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(4 * sigma_sq_d),
            'prod_coeff': 1.15,
            'exp_coeff': 1 / 2
        },
        # Network 7
        {
            'R_is_const': True,
            'R_denoising': np.sqrt(2.39 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.75 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 8
        {
            'R_is_const': False,
            'R_denoising': np.sqrt(2.06 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(30 * sigma_sq_d),
            'prod_coeff': 1.5,
            'exp_coeff': 1 / 2
        },
        # Network 9
        {
            'R_is_const': True,
            'R_denoising': np.sqrt(2 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 10
        {
            'R_is_const': True,
            'R_denoising': np.sqrt(2.19 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 11
        {
            'R_is_const': True,
            'R_denoising': np.sqrt(3.13 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(3.53 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },
        # Network 12
        {
            'R_is_const': True,
            'R_denoising': np.sqrt(1.94 * sigma_sq_D),
            'R_1st_order_nbhd': np.sqrt(2.39 * sigma_sq_D),
            'd_parallel': np.sqrt(20 * sigma_sq_d),
            'prod_coeff': 1.2,
            'exp_coeff': 1 / 2
        },

    ]

    return base_configs


def get_funnel_configs(sigma, d, D):
    base_configs = get_hyperparameter_configs(sigma, d, D)
    configs = []
    
    # take 3 models from base configurations and sweep with 0.5 granularity
    chosen_indices = [2, 6, 10]  # spread across the 12 original configs
    labels = []  # parallel labels: (base_idx, multiplier)
    for idx in chosen_indices:
        if idx < len(base_configs):
            base_i = base_configs[idx]
            R1_i = base_i['R_1st_order_nbhd']
            multipliers_05 = [0.0, 0.5, 1.0, 1.5, 2.0]
            for m in multipliers_05:
                cfg = dict(base_i)
                cfg['R_funnel'] = m * R1_i
                configs.append(cfg)
                labels.append((idx, m))

    return configs, labels


# build funnel configurations
configs, cfg_labels = get_funnel_configs(sigma, d, D)
print(f"Generated {len(configs)} funnel configurations (varying R_funnel)")
# Out:
# Generated 15 funnel configurations (varying R_funnel)

# %%
def train_networks(X_train, X_natural_train, configs, sigma, d, D, batch_size=4000):
    """
    Train all networks with different hyperparameter configurations.

    Args:
        X_train: Training data
        X_natural_train: Clean training data  
        configs: List of hyperparameter configurations
        sigma: Noise level
        d: Intrinsic dimension
        D: Ambient dimension
        batch_size: Batch size for training progress reporting

    Returns:
        Tuple of (networks, network_names, network_results, network_stats)
    """
    networks = []
    network_names = []
    network_results = []
    network_stats = []

    print(f"Training {len(configs)} networks with different hyperparameters...")
    print("=" * 80)

    for i, config in enumerate(configs):
        rf = config.get('R_funnel', 0.0)
        base_idx, m = cfg_labels[i]
        suffix = f" (x{m:.1f})"
        network_name = f"Base#{base_idx} R_funnel={rf:.4f}{suffix}"
        print(f"\nTraining {network_name}")
        print(f"Config: {config}")
        print("-" * 60)

        mt = ManifoldTraversal(
            intrinsic_dim=d,
            ambient_dim=D,
            sigma=sigma,
            **config
        )

        start_time = time.time()
        results = mt.fit(X_train, X_natural_train,
                         batch_size=batch_size, verbose=True)
        training_time = time.time() - start_time

        networks.append(mt)
        network_names.append(network_name)
        network_results.append(results)

        stats = mt.network.get_network_stats()
        stats['training_time'] = training_time
        stats['config'] = config
        network_stats.append(stats)

        print(f"Training completed in {training_time:.2f}s")
        print(f"Network stats: {stats}")
        print("~" * 60)

    print(f"\nAll {len(configs)} networks trained successfully!")
    return networks, network_names, network_results, network_stats

# %%
# train all networks
networks, network_names, network_results, network_stats = train_networks(X_train, X_natural_train, configs, sigma, d, D, batch_size=20000)
# Out:
# Training 15 networks with different hyperparameters...
# ================================================================================
#
# Training Base#2 R_funnel=0.0000 (x0.0)
# Config: {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.0}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 48.53s)
# 40000 samples processed (batch time: 72.91s)
# 60000 samples processed (batch time: 89.09s)
# 80000 samples processed (batch time: 96.80s)
# 100000 samples processed (batch time: 95.39s)
# Training complete! Total time: 402.73s
# Network statistics: {'num_landmarks': 1546, 'total_first_order_edges': 161366, 'total_zero_order_edges': 1947, 'total_points_assigned': 100000}
# Training completed in 402.73s
# Network stats: {'num_landmarks': 1546, 'total_first_order_edges': 161366, 'total_zero_order_edges': 1947, 'total_points_assigned': 100000, 'training_time': 402.7264847755432, 'config': {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.0}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#2 R_funnel=0.3498 (x0.5)
# Config: {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.34981137774520715}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 34.42s)
# 40000 samples processed (batch time: 65.98s)
# 60000 samples processed (batch time: 86.43s)
# 80000 samples processed (batch time: 98.21s)
# 100000 samples processed (batch time: 101.92s)
# Training complete! Total time: 386.95s
# Network statistics: {'num_landmarks': 1561, 'total_first_order_edges': 117209, 'total_zero_order_edges': 2553, 'total_points_assigned': 100000}
# Training completed in 386.95s
# Network stats: {'num_landmarks': 1561, 'total_first_order_edges': 117209, 'total_zero_order_edges': 2553, 'total_points_assigned': 100000, 'training_time': 386.9540538787842, 'config': {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.34981137774520715}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#2 R_funnel=0.6996 (x1.0)
# Config: {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.6996227554904143}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 53.18s)
# 40000 samples processed (batch time: 81.15s)
# 60000 samples processed (batch time: 96.28s)
# 80000 samples processed (batch time: 111.33s)
# 100000 samples processed (batch time: 118.95s)
# Training complete! Total time: 460.89s
# Network statistics: {'num_landmarks': 1869, 'total_first_order_edges': 157561, 'total_zero_order_edges': 14864, 'total_points_assigned': 100000}
# Training completed in 460.89s
# Network stats: {'num_landmarks': 1869, 'total_first_order_edges': 157561, 'total_zero_order_edges': 14864, 'total_points_assigned': 100000, 'training_time': 460.8864109516144, 'config': {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.6996227554904143}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#2 R_funnel=1.0494 (x1.5)
# Config: {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.0494341332356214}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 56.89s)
# 40000 samples processed (batch time: 82.63s)
# 60000 samples processed (batch time: 117.64s)
# 80000 samples processed (batch time: 133.32s)
# 100000 samples processed (batch time: 148.46s)
# Training complete! Total time: 538.94s
# Network statistics: {'num_landmarks': 2050, 'total_first_order_edges': 196284, 'total_zero_order_edges': 41310, 'total_points_assigned': 100000}
# Training completed in 538.94s
# Network stats: {'num_landmarks': 2050, 'total_first_order_edges': 196284, 'total_zero_order_edges': 41310, 'total_points_assigned': 100000, 'training_time': 538.9449410438538, 'config': {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.0494341332356214}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#2 R_funnel=1.3992 (x2.0)
# Config: {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.3992455109808286}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 52.71s)
# 40000 samples processed (batch time: 91.95s)
# 60000 samples processed (batch time: 124.04s)
# 80000 samples processed (batch time: 142.34s)
# 100000 samples processed (batch time: 152.24s)
# Training complete! Total time: 563.28s
# Network statistics: {'num_landmarks': 1931, 'total_first_order_edges': 163953, 'total_zero_order_edges': 48308, 'total_points_assigned': 100000}
# Training completed in 563.28s
# Network stats: {'num_landmarks': 1931, 'total_first_order_edges': 163953, 'total_zero_order_edges': 48308, 'total_points_assigned': 100000, 'training_time': 563.2786090373993, 'config': {'R_is_const': False, 'R_denoising': 0.6495290601659021, 'R_1st_order_nbhd': 0.6996227554904143, 'd_parallel': 0.04, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.3992455109808286}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#6 R_funnel=0.0000 (x0.0)
# Config: {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.0}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 5.12s)
# 40000 samples processed (batch time: 5.35s)
# 60000 samples processed (batch time: 5.57s)
# 80000 samples processed (batch time: 5.98s)
# 100000 samples processed (batch time: 6.17s)
# Training complete! Total time: 28.20s
# Network statistics: {'num_landmarks': 71, 'total_first_order_edges': 149, 'total_zero_order_edges': 181, 'total_points_assigned': 100000}
# Training completed in 28.20s
# Network stats: {'num_landmarks': 71, 'total_first_order_edges': 149, 'total_zero_order_edges': 181, 'total_points_assigned': 100000, 'training_time': 28.19960308074951, 'config': {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.0}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#6 R_funnel=0.3752 (x0.5)
# Config: {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.3752332607858744}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 5.30s)
# 40000 samples processed (batch time: 5.44s)
# 60000 samples processed (batch time: 5.68s)
# 80000 samples processed (batch time: 5.88s)
# 100000 samples processed (batch time: 5.84s)
# Training complete! Total time: 28.13s
# Network statistics: {'num_landmarks': 69, 'total_first_order_edges': 143, 'total_zero_order_edges': 178, 'total_points_assigned': 100000}
# Training completed in 28.13s
# Network stats: {'num_landmarks': 69, 'total_first_order_edges': 143, 'total_zero_order_edges': 178, 'total_points_assigned': 100000, 'training_time': 28.13036608695984, 'config': {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.3752332607858744}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#6 R_funnel=0.7505 (x1.0)
# Config: {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.7504665215717488}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 5.31s)
# 40000 samples processed (batch time: 5.78s)
# 60000 samples processed (batch time: 6.13s)
# 80000 samples processed (batch time: 6.23s)
# 100000 samples processed (batch time: 6.23s)
# Training complete! Total time: 29.68s
# Network statistics: {'num_landmarks': 70, 'total_first_order_edges': 146, 'total_zero_order_edges': 242, 'total_points_assigned': 100000}
# Training completed in 29.68s
# Network stats: {'num_landmarks': 70, 'total_first_order_edges': 146, 'total_zero_order_edges': 242, 'total_points_assigned': 100000, 'training_time': 29.681406021118164, 'config': {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.7504665215717488}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#6 R_funnel=1.1257 (x1.5)
# Config: {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.1256997823576231}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 5.38s)
# 40000 samples processed (batch time: 5.94s)
# 60000 samples processed (batch time: 6.11s)
# 80000 samples processed (batch time: 6.61s)
# 100000 samples processed (batch time: 6.68s)
# Training complete! Total time: 30.72s
# Network statistics: {'num_landmarks': 69, 'total_first_order_edges': 143, 'total_zero_order_edges': 270, 'total_points_assigned': 100000}
# Training completed in 30.72s
# Network stats: {'num_landmarks': 69, 'total_first_order_edges': 143, 'total_zero_order_edges': 270, 'total_points_assigned': 100000, 'training_time': 30.72207021713257, 'config': {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.1256997823576231}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#6 R_funnel=1.5009 (x2.0)
# Config: {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.5009330431434975}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 5.68s)
# 40000 samples processed (batch time: 6.10s)
# 60000 samples processed (batch time: 6.58s)
# 80000 samples processed (batch time: 7.06s)
# 100000 samples processed (batch time: 7.19s)
# Training complete! Total time: 32.61s
# Network statistics: {'num_landmarks': 70, 'total_first_order_edges': 146, 'total_zero_order_edges': 321, 'total_points_assigned': 100000}
# Training completed in 32.61s
# Network stats: {'num_landmarks': 70, 'total_first_order_edges': 146, 'total_zero_order_edges': 321, 'total_points_assigned': 100000, 'training_time': 32.610942125320435, 'config': {'R_is_const': True, 'R_denoising': 0.6996227554904143, 'R_1st_order_nbhd': 0.7504665215717488, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.5009330431434975}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#10 R_funnel=0.0000 (x0.0)
# Config: {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.0}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 4.41s)
# 40000 samples processed (batch time: 4.50s)
# 60000 samples processed (batch time: 4.63s)
# 80000 samples processed (batch time: 4.69s)
# 100000 samples processed (batch time: 4.72s)
# Training complete! Total time: 22.94s
# Network statistics: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 96, 'total_points_assigned': 100000}
# Training completed in 22.94s
# Network stats: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 96, 'total_points_assigned': 100000, 'training_time': 22.944371938705444, 'config': {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.0}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#10 R_funnel=0.4251 (x0.5)
# Config: {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.42513056817876554}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 4.39s)
# 40000 samples processed (batch time: 4.51s)
# 60000 samples processed (batch time: 4.65s)
# 80000 samples processed (batch time: 4.70s)
# 100000 samples processed (batch time: 4.74s)
# Training complete! Total time: 23.00s
# Network statistics: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 96, 'total_points_assigned': 100000}
# Training completed in 23.00s
# Network stats: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 96, 'total_points_assigned': 100000, 'training_time': 22.995572090148926, 'config': {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.42513056817876554}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#10 R_funnel=0.8503 (x1.0)
# Config: {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.8502611363575311}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 4.42s)
# 40000 samples processed (batch time: 4.47s)
# 60000 samples processed (batch time: 4.65s)
# 80000 samples processed (batch time: 4.74s)
# 100000 samples processed (batch time: 4.75s)
# Training complete! Total time: 23.04s
# Network statistics: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 106, 'total_points_assigned': 100000}
# Training completed in 23.04s
# Network stats: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 106, 'total_points_assigned': 100000, 'training_time': 23.03555130958557, 'config': {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 0.8502611363575311}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#10 R_funnel=1.2754 (x1.5)
# Config: {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.2753917045362966}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 4.46s)
# 40000 samples processed (batch time: 4.47s)
# 60000 samples processed (batch time: 4.65s)
# 80000 samples processed (batch time: 4.80s)
# 100000 samples processed (batch time: 4.78s)
# Training complete! Total time: 23.17s
# Network statistics: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 107, 'total_points_assigned': 100000}
# Training completed in 23.17s
# Network stats: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 107, 'total_points_assigned': 100000, 'training_time': 23.16827893257141, 'config': {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.2753917045362966}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# Training Base#10 R_funnel=1.7005 (x2.0)
# Config: {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.7005222727150622}
# ------------------------------------------------------------
# Training manifold traversal on 100000 samples...
# 20000 samples processed (batch time: 4.38s)
# 40000 samples processed (batch time: 4.49s)
# 60000 samples processed (batch time: 4.87s)
# 80000 samples processed (batch time: 4.87s)
# 100000 samples processed (batch time: 4.78s)
# Training complete! Total time: 23.39s
# Network statistics: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 113, 'total_points_assigned': 100000}
# Training completed in 23.39s
# Network stats: {'num_landmarks': 39, 'total_first_order_edges': 59, 'total_zero_order_edges': 113, 'total_points_assigned': 100000, 'training_time': 23.39298677444458, 'config': {'R_is_const': True, 'R_denoising': 0.8006397442045955, 'R_1st_order_nbhd': 0.8502611363575311, 'd_parallel': 0.06324555320336758, 'prod_coeff': 1.2, 'exp_coeff': 0.5, 'R_funnel': 1.7005222727150622}}
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
#
# All 15 networks trained successfully!

# %%
def analyze_networks(networks, network_names, X_test, X_natural_test, N_test, num_test_samples=None):
    """
    Analyze performance of all trained networks.

    Args:
        networks: List of trained ManifoldTraversal instances
        network_names: List of network names
        X_test: Test data
        X_natural_test: Clean test data  
        N_test: Number of test samples
        num_test_samples: Number of test samples to use (None for all)

    Returns:
        analysis_results: List of analysis results for each network
    """
    if num_test_samples is None:
        num_test_samples = N_test

    print(f"\nAnalyzing performance on {num_test_samples} test samples...")
    print("=" * 80)

    analysis_results = []

    for i, (mt, name) in enumerate(zip(networks, network_names)):
        print(f"Analyzing {name}...")

        results = mt.analyze_performance(
            X_test, X_natural_test,
            num_samples=num_test_samples
        )

        analysis_results.append(results)

        print(f"  Exhaustive Search: Error={results['exhaustive']['avg_distance']:.6f}, "
              f"Complexity={results['exhaustive']['avg_mults']:.1f}")
        print(f"  Mixed Order (MT): Error={results['mixed_order']['avg_distance']:.6f}, "
              f"Complexity={results['mixed_order']['avg_mults']:.1f}")
        print(f"  First Order Only: Error={results['first_order_only']['avg_distance']:.6f}, "
              f"Complexity={results['first_order_only']['avg_mults']:.1f}")
        print(f"  Zero Order Only: Error={results['zero_order_only']['avg_distance']:.6f}, "
              f"Complexity={results['zero_order_only']['avg_mults']:.1f}")
        print()

    print("Analysis complete.")
    return analysis_results


# analyze all networks
analysis_results = analyze_networks(networks, network_names, X_test, X_natural_test, N_test)
# Out:
# Analyzing performance on 20000 test samples...
# ================================================================================
# Analyzing Base#2 R_funnel=0.0000 (x0.0)...
#   Exhaustive Search: Error=0.010264, Complexity=3166208.0
#   Mixed Order (MT): Error=0.012589, Complexity=50403.0
#   First Order Only: Error=0.368370, Complexity=20455.3
#   Zero Order Only: Error=0.012219, Complexity=576517.2
#
# Analyzing Base#2 R_funnel=0.3498 (x0.5)...
#   Exhaustive Search: Error=0.010389, Complexity=3196928.0
#   Mixed Order (MT): Error=0.011908, Complexity=76477.0
#   First Order Only: Error=0.350979, Complexity=19553.8
#   Zero Order Only: Error=0.011562, Complexity=637961.4
#
# Analyzing Base#2 R_funnel=0.6996 (x1.0)...
#   Exhaustive Search: Error=0.011624, Complexity=3827712.0
#   Mixed Order (MT): Error=0.012075, Complexity=125239.0
#   First Order Only: Error=0.468048, Complexity=18574.3
#   Zero Order Only: Error=0.011798, Complexity=734102.6
#
# Analyzing Base#2 R_funnel=1.0494 (x1.5)...
#   Exhaustive Search: Error=0.011389, Complexity=4198400.0
#   Mixed Order (MT): Error=0.013272, Complexity=210669.4
#   First Order Only: Error=0.378533, Complexity=18682.4
#   Zero Order Only: Error=0.011397, Complexity=697063.4
#
# Analyzing Base#2 R_funnel=1.3992 (x2.0)...
#   Exhaustive Search: Error=0.011325, Complexity=3954688.0
#   Mixed Order (MT): Error=0.011840, Complexity=311814.0
#   First Order Only: Error=0.389101, Complexity=20010.5
#   Zero Order Only: Error=0.011632, Complexity=881269.9
#
# Analyzing Base#6 R_funnel=0.0000 (x0.0)...
#   Exhaustive Search: Error=0.025141, Complexity=145408.0
#   Mixed Order (MT): Error=0.026713, Complexity=39621.9
#   First Order Only: Error=0.320572, Complexity=21739.9
#   Zero Order Only: Error=0.027525, Complexity=39228.6
#
# Analyzing Base#6 R_funnel=0.3752 (x0.5)...
#   Exhaustive Search: Error=0.028819, Complexity=141312.0
#   Mixed Order (MT): Error=0.030055, Complexity=42543.7
#   First Order Only: Error=0.468109, Complexity=17707.2
#   Zero Order Only: Error=0.029614, Complexity=37672.1
#
# Analyzing Base#6 R_funnel=0.7505 (x1.0)...
#   Exhaustive Search: Error=0.027228, Complexity=143360.0
#   Mixed Order (MT): Error=0.030899, Complexity=49240.5
#   First Order Only: Error=0.412208, Complexity=18677.9
#   Zero Order Only: Error=0.032916, Complexity=49063.2
#
# Analyzing Base#6 R_funnel=1.1257 (x1.5)...
#   Exhaustive Search: Error=0.029270, Complexity=141312.0
#   Mixed Order (MT): Error=0.029957, Complexity=60888.3
#   First Order Only: Error=0.465040, Complexity=17696.8
#   Zero Order Only: Error=0.031655, Complexity=64183.4
#
# Analyzing Base#6 R_funnel=1.5009 (x2.0)...
#   Exhaustive Search: Error=0.028140, Complexity=143360.0
#   Mixed Order (MT): Error=0.028427, Complexity=70634.2
#   First Order Only: Error=0.431606, Complexity=19549.4
#   Zero Order Only: Error=0.028222, Complexity=65057.0
#
# Analyzing Base#10 R_funnel=0.0000 (x0.0)...
#   Exhaustive Search: Error=0.050103, Complexity=79872.0
#   Mixed Order (MT): Error=0.050223, Complexity=40087.1
#   First Order Only: Error=1.041133, Complexity=8194.0
#   Zero Order Only: Error=0.050212, Complexity=26208.4
#
# Analyzing Base#10 R_funnel=0.4251 (x0.5)...
#   Exhaustive Search: Error=0.050079, Complexity=79872.0
#   Mixed Order (MT): Error=0.050178, Complexity=40408.0
#   First Order Only: Error=1.041133, Complexity=8194.0
#   Zero Order Only: Error=0.050178, Complexity=26204.4
#
# Analyzing Base#10 R_funnel=0.8503 (x1.0)...
#   Exhaustive Search: Error=0.050099, Complexity=79872.0
#   Mixed Order (MT): Error=0.050230, Complexity=40757.2
#   First Order Only: Error=1.041133, Complexity=8194.0
#   Zero Order Only: Error=0.050207, Complexity=26854.3
#
# Analyzing Base#10 R_funnel=1.2754 (x1.5)...
#   Exhaustive Search: Error=0.050097, Complexity=79872.0
#   Mixed Order (MT): Error=0.050206, Complexity=40898.8
#   First Order Only: Error=1.041133, Complexity=8194.0
#   Zero Order Only: Error=0.050206, Complexity=26995.7
#
# Analyzing Base#10 R_funnel=1.7005 (x2.0)...
#   Exhaustive Search: Error=0.050077, Complexity=79872.0
#   Mixed Order (MT): Error=0.050212, Complexity=40903.0
#   First Order Only: Error=1.041133, Complexity=8194.0
#   Zero Order Only: Error=0.050176, Complexity=26994.8
#
# Analysis complete.

# %%
def plot_training_curve(network_results, network_names, sigma, d, D, network_idx=0):
    """
    Plot training error curve for a specific network.

    Args:
        network_results: List of training results
        network_names: List of network names
        sigma: Noise level
        d: Intrinsic dimension
        D: Ambient dimension
        network_idx: Index of network to plot (default: first network)
    """
    if network_idx >= len(network_results):
        raise ValueError(f"Network index {network_idx} out of range")

    results = network_results[network_idx]

    sigma_sq_d = [sigma ** 2 * d] * len(results.mean_MT_error)
    sigma_sq_D = [sigma ** 2 * D] * len(results.mean_MT_error)

    plt.figure(figsize=(10, 6))
    plt.plot(results.mean_MT_error, color='orange', label='MT training')
    plt.plot(sigma_sq_d, color='green', label=r'$\sigma^2 d$')
    plt.plot(sigma_sq_D, color='blue', label=r'$\sigma^2 D$')
    plt.legend()
    plt.xlabel('Number of Samples')
    plt.ylabel('Mean Square Error (Train)')
    plt.title(f'Training Error Curve - {network_names[network_idx]}')
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.5)
    plt.show()


# plot training curve for the first network
plot_training_curve(network_results, network_names, sigma, d, D, network_idx=0)

# %%
def plot_complexity_accuracy_tradeoff(analysis_results, configs, networks):
    """
    Plot computational complexity vs accuracy tradeoff (MT vs NN).

    Args:
        analysis_results: List of analysis results
        configs: List of hyperparameter configurations
        networks: List of trained networks
    """
    mt_accuracies = [r['mixed_order']['avg_distance'] for r in analysis_results]
    mt_complexities = [r['mixed_order']['avg_mults'] for r in analysis_results]
    nn_accuracies = [r['exhaustive']['avg_distance'] for r in analysis_results]
    nn_complexities = [r['exhaustive']['avg_mults'] for r in analysis_results]

    plt.figure(figsize=(10, 6))

    for i in range(len(networks)):
        has_funnel = configs[i].get('R_funnel', 0.0) > 0.0
        marker_mt = '^' if has_funnel else 'o'
        plt.scatter(mt_accuracies[i], np.log10(mt_complexities[i]),
                    marker=marker_mt, color='blue', s=60,
                    label='MT (funnel)' if has_funnel else 'MT (no funnel)')
        plt.scatter(nn_accuracies[i], np.log10(nn_complexities[i]),
                    marker='s', color='red', s=60)

    plt.title('Computational Complexity vs. Accuracy')
    plt.ylabel("log of (\#Multiplications per sample)")
    plt.xlabel("Mean Squared Error")

    legend_elements = [
        Line2D([0], [0], marker='o', color='w', label='MT (no funnel)',
               markerfacecolor='blue', markersize=8),
        Line2D([0], [0], marker='^', color='w', label='MT (funnel)',
               markerfacecolor='blue', markersize=8),
        Line2D([0], [0], marker='s', color='w', label='Nearest Neighbor',
               markerfacecolor='red', markersize=8),
    ]
    plt.legend(handles=legend_elements)
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.5)
    plt.show()


# plot complexity vs accuracy tradeoff
plot_complexity_accuracy_tradeoff(analysis_results, configs, networks)
# Out:
# <>:27: SyntaxWarning: invalid escape sequence '\#'
# <>:27: SyntaxWarning: invalid escape sequence '\#'
# /var/folders/3q/1dnvg5nn0_73w1fyyj_hk0hc0000gn/T/ipykernel_18704/1956946987.py:27: SyntaxWarning: invalid escape sequence '\#'
#   plt.ylabel("log of (\#Multiplications per sample)")

# %%
def plot_ablation_study(analysis_results, configs, networks):
    """
    Plot ablation study comparing mixed-order, first-order, and zero-order methods.

    Args:
        analysis_results: List of analysis results
        configs: List of hyperparameter configurations  
        networks: List of trained networks
    """
    mt_accuracies = [r['mixed_order']['avg_distance'] for r in analysis_results]
    mt_complexities = [r['mixed_order']['avg_mults'] for r in analysis_results]
    fom_accuracies = [r['first_order_only']['avg_distance'] for r in analysis_results]
    fom_complexities = [r['first_order_only']['avg_mults'] for r in analysis_results]
    zom_accuracies = [r['zero_order_only']['avg_distance'] for r in analysis_results]
    zom_complexities = [r['zero_order_only']['avg_mults'] for r in analysis_results]

    plt.figure(figsize=(10, 6))

    for i in range(len(networks)):
        has_funnel = configs[i].get('R_funnel', 0.0) > 0.0
        marker_mt = '^' if has_funnel else 'o'
        plt.scatter(mt_accuracies[i], np.log10(mt_complexities[i]),
                    marker=marker_mt, color='blue', s=60,
                    label='MT (funnel)' if has_funnel else 'MT (no funnel)')
        plt.scatter(fom_accuracies[i], np.log10(fom_complexities[i]),
                    marker='*', color='orange', s=60)
        plt.scatter(zom_accuracies[i], np.log10(zom_complexities[i]),
                    marker='x', color='purple', s=60)

    plt.title('Ablation Study of Mixed-Order Method')
    plt.ylabel("log of (\#Multiplications per sample)")
    plt.xlabel("Mean Squared Error")

    legend_elements = [
        Line2D([0], [0], marker='o', color='w',
               label='Mixed-Order (no funnel)',
               markerfacecolor='blue', markersize=8),
        Line2D([0], [0], marker='^', color='w',
               label='Mixed-Order (funnel)',
               markerfacecolor='blue', markersize=8),
        Line2D([0], [0], marker='*', color='w',
               label='First-Order Only',
               markerfacecolor='orange', markersize=8),
        Line2D([0], [0], marker='x', color='w',
               label='Zero-Order Only',
               markeredgecolor='purple', markersize=8, linestyle='None'),
    ]
    plt.legend(handles=legend_elements)
    plt.grid(True, linestyle='--', linewidth=0.5, alpha=0.5)
    plt.show()


# plot ablation study
plot_ablation_study(analysis_results, configs, networks)
# Out:
# <>:31: SyntaxWarning: invalid escape sequence '\#'
# <>:31: SyntaxWarning: invalid escape sequence '\#'
# /var/folders/3q/1dnvg5nn0_73w1fyyj_hk0hc0000gn/T/ipykernel_18704/2851676541.py:31: SyntaxWarning: invalid escape sequence '\#'
#   plt.ylabel("log of (\#Multiplications per sample)")
